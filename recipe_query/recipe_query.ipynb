# %% [markdown]
# ## Create a database for recipes datafile

# %%
import sqlite3
import pandas as pd

# creates a databse in current directory called `temp.db`
conn = sqlite3.connect("temp.db")

# upload recipes scraped from allrecipes.com to database
recipes = pd.read_csv("Recipes.csv")
recipes.to_sql("recipes", conn, if_exists = "replace", index=False)

# check if dataset has been successfully uploaded to database
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table'")
print(cursor.fetchall())
conn.close()
# Out:
# [('recipes',)]

# %% [markdown]
# ## Query function for accessing recipes based on certain criteria

# %%
# to convert "ingredients_list" in `recipes` into list of ingredients
ing_text = recipes.loc[0, "ingredients_list"]
ing_list = ing_text.rsplit(",")
ing_list
# Out:
# ['sweet onions',
#  ' sliced 1/2 inch thick',
#  'buttermilk',
#  'egg',
#  'all-purpose flour',
#  "RedHot Chile and Lime Seasoning Blend (such as Frank's®)",
#  'adobo all-purpose seasoning (such as Goya®)',
#  'panko bread crumbs',
#  'adobo all-purpose seasoning (such as Goya®)',
#  "RedHot Chile and Lime Seasoning Blend (such as Frank's®)",
#  'olive oil cooking spray',
#  'kosher salt',
#  ' or to taste']

# %%
import pandas as pd
recipes = pd.read_csv("Recipes.csv")
recipes.columns
# Out:
# Index(['recipe_name', 'category_name', 'rating', 'prep_time', 'cook_time',
#        'total_time', 'num_servings_per_recipe', 'ingredients_list',
#        'direction_list', 'calories_per_serving', 'total_fat (g)',
#        'saturated_fat (g)', 'sodium (mg)', 'protein (g)', 'carbs (g)',
#        'fiber (g)', 'sugar (g)', 'cholesterol (mg)', 'vitamin_c (mg)',
#        'calcium (mg)', 'iron (mg)', 'potassium (mg)', 'recipe_link'],
#       dtype='object')

# %% [markdown]
# ## Testing `query_recipes()`

# %%
from recipe_query import query_recipes
import inspect
print(inspect.getsource(query_recipes))
# Out:
# def query_recipes(db_file, ingredients = [], time = float('inf'),
#                   min_calories = 0, max_calories = float('inf')):
#     """ returns a list of recipes that contains given ingredients, is within available
#     time, and each serving of recipe has calories within the range [min_calories, max_calories]
#
#     Args:
#         db_file (string): file name for the database.
#         ingredients (list, optional): a list of ingredients (string). Defaults to [].
#         time (float, optional): maximum minutes that user has available to cook. Defaults to inf.
#         min_calories (float, optional): minimum calories that user wants per serving. Defaults to 0.
#         max_calories (float, optional): maximum calories that user wants per serving. Defaults to inf.
#
#     Returns:
#         df (Pandas dataframe): a dataframe of recipes that match the given inputs
#     """
#
#     # Replace infinity with a large number for SQLite compatibility
#     max_time = time if time != float('inf') else 1e9
#     max_cal = max_calories if max_calories != float('inf') else 1e9
#
#     with sqlite3.connect(db_file) as conn:
#         # Fetch all recipes that match calorie and time constraints
#         query = f"""
#             SELECT * FROM recipes
#             WHERE calories_per_serving >= {min_calories}
#             AND calories_per_serving <= {max_cal}
#             AND total_time <= {max_time}
#         """
#         df = pd.read_sql_query(query, conn)
#
#     # Filter the dataframe for recipes that contain all the required ingredients
#     df = df[df['ingredients_list'].apply(lambda x: contains_all_ingredients(x.split(", "), ingredients))]
#
#     return df

# %%
import pandas as pd
recipes = pd.read_csv("Recipes.csv")
recipes.head()
# Out:
#                                 recipe_name             category_name  rating  \
# 0               Air Fryer Spicy Onion Rings       Air Fryer Recipes\n     5.0
# 1               Stuffed Chicken Cordon Bleu     Chicken Cordon Bleu\n     5.0
# 2  Hearty Chicken Cacciatore Soup with Rice      Chicken Cacciatore\n     NaN
# 3       Chicken and Dumplings with Biscuits   Chicken and Dumplings\n     4.1
# 4                     Margo's Chicken Adobo           Chicken Adobo\n     4.5
#
#   prep_time      cook_time     total_time num_servings_per_recipe  \
# 0   20 mins        10 mins           1 hr                      4
# 1   20 mins        40 mins   1 hr 15 mins                      4
# 2   10 mins   1 hr 45 mins   1 hr 55 mins                     10
# 3       NaN            NaN            NaN                      8
# 4   10 mins           1 hr   1 hr 10 mins                      8
#
#                                     ingredients_list  \
# 0  sweet onions, sliced 1/2 inch thick,buttermilk...
# 1  skinless, boneless chicken breast halves,bacon...
# 2  chicken broth,condensed tomato soup,water,dice...
# 3  whole chicken, cut into pieces,salt,freshly gr...
# 4  canola oil,chicken drumsticks and thighs,onion...
#
#                                       direction_list  calories_per_serving  \
# 0   Whisk together buttermilk, egg, flour, chile ...                 230.0
# 1   Preheat the oven to 400 degrees F (200 degree...                 877.0
# 2   Combine chicken broth, condensed soup, 2 cans...                 250.0
# 3   Put chicken pieces in a large pot over medium...                 696.0
# 4   Heat canola oil in a large Dutch oven over me...                 323.0
#
#    ... protein (g) carbs (g) fiber (g) sugar (g) cholesterol (mg)  \
# 0  ...         10g       53g        2g       NaN             48mg
# 1  ...         66g       44g        3g        8g            291mg
# 2  ...         15g       35g        2g       NaN             38mg
# 3  ...         37g       86g        6g        5g            106mg
# 4  ...         30g        7g        1g        2g             96mg
#
#   vitamin_c (mg) calcium (mg) iron (mg) potassium (mg)  \
# 0            NaN          NaN       NaN          197mg
# 1            3mg        636mg       4mg          969mg
# 2            NaN          NaN       NaN          406mg
# 3           49mg         64mg       5mg         1398mg
# 4            3mg         40mg       3mg          347mg
#
#                                          recipe_link
# 0  https://www.allrecipes.com/recipe/8465728/air-...
# 1  https://www.allrecipes.com/recipe/283793/stuff...
# 2  https://www.allrecipes.com/recipe/8300735/hear...
# 3  https://www.allrecipes.com/recipe/8810/chicken...
# 4  https://www.allrecipes.com/recipe/218510/margo...
#
# [5 rows x 23 columns]

# %%
import sqlite3
import pandas as pd

# creates a databse in current directory called `temp.db`
conn = sqlite3.connect("temp.db")

# upload recipes scraped from allrecipes.com to database
recipes = pd.read_csv("Recipes.csv")
recipes.to_sql("recipes", conn, if_exists = "replace", index=False)

df = query_recipes("temp.db", 
                   ingredients=["sugar", "apple"]
                   )
df.head()
# Out:
#                                  recipe_name              category_name  \
# 13  Roasted Acorn, Butternut, and Apple Soup   Butternut Squash Soups\n
# 17            Andy's Jalapeno Zucchini Bread          Zucchini Breads\n
# 19   Gluten-Free Zucchini Bread (or Muffins)          Zucchini Breads\n
# 23               Vegan Zucchini Banana Bread          Zucchini Breads\n
# 25            Zucchini Bread with Pineapple           Zucchini Breads\n
#
#     rating prep_time      cook_time     total_time num_servings_per_recipe  \
# 13     4.3   20 mins   1 hr 10 mins   1 hr 30 mins                     12
# 17     4.3   20 mins           1 hr   1 hr 20 mins                     16
# 19     3.7   20 mins        50 mins   1 hr 10 mins                      8
# 23     3.8   20 mins           1 hr   1 hr 40 mins                     12
# 25     4.8   20 mins           1 hr   1 hr 20 mins                     18
#
#                                      ingredients_list  \
# 13  butter, softened,brown sugar,honey,butternut s...
# 17  all-purpose flour,white sugar,brown sugar,grou...
# 19  gluten-free flour,ground cinnamon,salt,baking ...
# 23  all-purpose flour,salt,baking soda,baking powd...
# 25  all-purpose flour,baking soda,ground cinnamon,...
#
#                                        direction_list  calories_per_serving  \
# 13   Preheat oven to 325 degrees F (165 degrees C)...                 279.0
# 17   Preheat oven to 350 degrees F (175 degrees C)...                 269.0
# 19   Preheat oven to 325 degrees F (165 degrees C)...                 561.0
# 23   Preheat the oven to 325 degrees F (165 degree...                 350.0
# 25   Preheat the oven to 325 degrees F (165 degree...                 362.0
#
#     ... protein (g) carbs (g) fiber (g) sugar (g) cholesterol (mg)  \
# 13  ...          3g       51g        5g       32g             20mg
# 17  ...          4g       46g        1g       27g             35mg
# 19  ...          8g       99g        6g       62g             70mg
# 23  ...          4g       63g        2g       36g             None
# 25  ...          5g       49g        2g       30g             31mg
#
#    vitamin_c (mg) calcium (mg) iron (mg) potassium (mg)  \
# 13           30mg        102mg       2mg          666mg
# 17            4mg         32mg       2mg          110mg
# 19            6mg         59mg       1mg          137mg
# 23            9mg         75mg       2mg          233mg
# 25            5mg         31mg       2mg          206mg
#
#                                           recipe_link
# 13  https://www.allrecipes.com/recipe/235570/roast...
# 17  https://www.allrecipes.com/recipe/239859/andys...
# 19  https://www.allrecipes.com/recipe/244775/glute...
# 23  https://www.allrecipes.com/recipe/215489/vegan...
# 25  https://www.allrecipes.com/recipe/215089/zucch...
#
# [5 rows x 23 columns]

# %%
df = query_recipes("temp.db", 
                   min_calories=1000
                   )
df.head()
# Out:
#                         recipe_name            category_name  rating  \
# 0           Zucchini Bread in a Jar        Zucchini Breads\n     4.7
# 1  Overnight French Toast Casserole   Breakfast Casseroles\n     4.7
# 2        Brined Thanksgiving Turkey                 Brines\n     4.9
# 3    Salmon Brine That's Oh-So-Fine                 Brines\n     4.7
# 4                       Wet Burrito               Burritos\n     4.6
#
#   prep_time       cook_time      total_time num_servings_per_recipe  \
# 0   30 mins            1 hr   3 hrs 30 mins                      4
# 1   15 mins         45 mins           9 hrs                      5
# 2   30 mins   6 hrs 30 mins     1 day 7 hrs                     12
# 3   10 mins            None         10 mins                      1
# 4   30 mins         30 mins            1 hr                      4
#
#                                     ingredients_list  \
# 0  raisins,hot water,shortening for greasing,whit...
# 1  butter, melted,light brown sugar,cinnamon,Fren...
# 2  chicken broth,apple juice (Optional),light bro...
# 3  whole black peppercorns,water,kosher salt,brow...
# 4  lean ground beef,chopped onion, divided,garlic...
#
#                                       direction_list  calories_per_serving  \
# 0   Preheat the oven to 325 degrees F (165 degree...                1393.0
# 1   Pour melted butter into an 11x15-inch baking ...                1077.0
# 2   Gather all ingredients.\n,ALLRECIPES / QI AI,...                1320.0
# 3   Place peppercorns in a plastic bag and seal. ...                2039.0
# 4   Preheat the oven to 375 degrees F (190 degree...                1191.0
#
#    ... protein (g) carbs (g) fiber (g) sugar (g) cholesterol (mg)  \
# 0  ...         18g      164g        7g      102g            140mg
# 1  ...         23g      144g        3g       93g            367mg
# 2  ...        155g       36g        3g       31g            455mg
# 3  ...          4g      531g        5g      500g             None
# 4  ...         59g      104g       14g       10g            179mg
#
#   vitamin_c (mg) calcium (mg) iron (mg) potassium (mg)  \
# 0           12mg        126mg       6mg          734mg
# 1            0mg        285mg       5mg          490mg
# 2            6mg        191mg      10mg         1710mg
# 3           22mg        515mg       8mg         1061mg
# 4           27mg        762mg      13mg         1425mg
#
#                                          recipe_link
# 0  https://www.allrecipes.com/recipe/256341/zucch...
# 1  https://www.allrecipes.com/recipe/275838/overn...
# 2  https://www.allrecipes.com/recipe/234092/brine...
# 3  https://www.allrecipes.com/recipe/234485/salmo...
# 4  https://www.allrecipes.com/recipe/222013/wet-b...
#
# [5 rows x 23 columns]

# %%
df = query_recipes("temp.db", 
                   max_calories=1000
                   )
df.head()
# Out:
#                                 recipe_name           category_name  rating  \
# 0               Air Fryer Spicy Onion Rings     Air Fryer Recipes\n     5.0
# 1               Stuffed Chicken Cordon Bleu   Chicken Cordon Bleu\n     5.0
# 2  Hearty Chicken Cacciatore Soup with Rice    Chicken Cacciatore\n     NaN
# 3                     Margo's Chicken Adobo         Chicken Adobo\n     4.5
# 4                   Run For The Roses Pie I             Chess Pie\n     4.2
#
#   prep_time      cook_time     total_time num_servings_per_recipe  \
# 0   20 mins        10 mins           1 hr                      4
# 1   20 mins        40 mins   1 hr 15 mins                      4
# 2   10 mins   1 hr 45 mins   1 hr 55 mins                     10
# 3   10 mins           1 hr   1 hr 10 mins                      8
# 4   30 mins        45 mins   1 hr 20 mins                     16
#
#                                     ingredients_list  \
# 0  sweet onions, sliced 1/2 inch thick,buttermilk...
# 1  skinless, boneless chicken breast halves,bacon...
# 2  chicken broth,condensed tomato soup,water,dice...
# 3  canola oil,chicken drumsticks and thighs,onion...
# 4  chopped walnuts,bourbon,white sugar,light corn...
#
#                                       direction_list  calories_per_serving  \
# 0   Whisk together buttermilk, egg, flour, chile ...                 230.0
# 1   Preheat the oven to 400 degrees F (200 degree...                 877.0
# 2   Combine chicken broth, condensed soup, 2 cans...                 250.0
# 3   Heat canola oil in a large Dutch oven over me...                 323.0
# 4   Preheat oven to 350 degrees F (175 degrees C)...                 394.0
#
#    ... protein (g) carbs (g) fiber (g) sugar (g) cholesterol (mg)  \
# 0  ...         10g       53g        2g      None             48mg
# 1  ...         66g       44g        3g        8g            291mg
# 2  ...         15g       35g        2g      None             38mg
# 3  ...         30g        7g        1g        2g             96mg
# 4  ...          5g       46g        2g       24g             62mg
#
#   vitamin_c (mg) calcium (mg) iron (mg) potassium (mg)  \
# 0           None         None      None          197mg
# 1            3mg        636mg       4mg          969mg
# 2           None         None      None          406mg
# 3            3mg         40mg       3mg          347mg
# 4            0mg         24mg       1mg          104mg
#
#                                          recipe_link
# 0  https://www.allrecipes.com/recipe/8465728/air-...
# 1  https://www.allrecipes.com/recipe/283793/stuff...
# 2  https://www.allrecipes.com/recipe/8300735/hear...
# 3  https://www.allrecipes.com/recipe/218510/margo...
# 4  https://www.allrecipes.com/recipe/23165/run-fo...
#
# [5 rows x 23 columns]

# %%
df = query_recipes("temp.db", 
                   ingredients=["sugar", "apple"],
                   max_calories=200,
                   min_calories=100
                   )
df.head()
# Out:
#                        recipe_name       category_name  rating prep_time  \
# 0          Savory Zucchini Muffins   Zucchini Breads\n     4.5   25 mins
# 1   Healthier Mom's Zucchini Bread   Zucchini Breads\n     4.5   20 mins
# 2  Whole Wheat Zucchini Herb Bread   Zucchini Breads\n     4.5    5 mins
# 3             Zucchini Gingerbread   Zucchini Breads\n     4.3   15 mins
# 4            Zucchini Carrot Bread   Zucchini Breads\n     3.6   15 mins
#
#   cook_time      total_time num_servings_per_recipe  \
# 0   35 mins    1 hr 10 mins                     16
# 1      1 hr   2 hrs 20 mins                     24
# 2     3 hrs    3 hrs 5 mins                     10
# 3   50 mins    1 hr 15 mins                     20
# 4      1 hr    1 hr 15 mins                     16
#
#                                     ingredients_list  \
# 0  olive oil,chopped onion,garlic, chopped,choppe...
# 1  all-purpose flour,white whole wheat flour,salt...
# 2  water,honey,vegetable oil,grated zucchini,whol...
# 3  cooking spray,brown sugar,vanilla yogurt,molas...
# 4  all-purpose flour,ground cinnamon,salt,baking ...
#
#                                       direction_list  calories_per_serving  \
# 0   Preheat oven to 375 degrees F (190 degrees C)...                 181.0
# 1   Preheat oven to 325 degrees F (165 degrees C)...                 190.0
# 2   Place ingredients in the pan of the bread mac...                 153.0
# 3   Preheat the oven to 325 degrees F (165 degree...                 163.0
# 4   Preheat the oven to 350 degrees F (175 degree...                 184.0
#
#    ... protein (g) carbs (g) fiber (g) sugar (g) cholesterol (mg)  \
# 0  ...          5g       19g        1g        3g             44mg
# 1  ...          4g       26g        2g       13g             24mg
# 2  ...          5g       28g        2g        2g             None
# 3  ...          4g       29g        1g       14g             28mg
# 4  ...          4g       40g        1g       21g             35mg
#
#   vitamin_c (mg) calcium (mg) iron (mg) potassium (mg)  \
# 0            5mg         86mg       1mg          140mg
# 1            3mg         35mg       1mg          116mg
# 2            2mg         16mg       2mg          105mg
# 3            3mg         52mg       1mg          195mg
# 4            3mg         25mg       1mg          107mg
#
#                                          recipe_link
# 0  https://www.allrecipes.com/recipe/204983/savor...
# 1  https://www.allrecipes.com/recipe/222078/healt...
# 2  https://www.allrecipes.com/recipe/6841/whole-w...
# 3  https://www.allrecipes.com/recipe/218899/zucch...
# 4  https://www.allrecipes.com/recipe/239724/zucch...
#
# [5 rows x 23 columns]
