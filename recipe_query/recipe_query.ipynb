# %% [markdown]
# ## Testing `query_recipes()`

# %%
import sqlite3
import pandas as pd
from recipe_query import query_recipes

# creates a databse in current directory called `temp.db`
conn = sqlite3.connect("temp.db")

# upload recipes scraped from allrecipes.com to database
recipes = pd.read_csv("../datasets/cleaned_recipes.csv")
recipes.to_sql("recipes", conn, if_exists = "replace", index=False)

df = query_recipes("temp.db", 
                   ingredients=['onion', 'lime', 'bread', 'milk', 'egg', 'flour']
                   )
df.head()
# Out:
#                                              recipe_name       category_name  \
# 0                            Air Fryer Spicy Onion Rings   Air Fryer Recipes
# 2504              Kitchen Sink Hash Brown and Egg Waffle             Waffles
# 4237                                  Air Fryer Calamari               Tapas
# 12232                           Homemade English Muffins     English Muffins
# 2790   Hot Ube Pandesal (Filipino Purple Yam Bread Ro...                Yams
#
#        rating  prep_time  cook_time  additional_time  total_time  \
# 0         5.0       20.0       10.0             30.0        60.0
# 2504      4.1       15.0        5.0              0.0        20.0
# 4237      4.5       10.0       10.0              0.0        20.0
# 12232     4.7       25.0       15.0             90.0       130.0
# 2790      4.0       25.0       20.0            110.0       155.0
#
#       num_servings_per_recipe  \
# 0                          4
# 2504                       4
# 4237                       4
# 12232                     16
# 2790                      24
#
#                                         ingredients_list  \
# 0      sweet onions, sliced 1/2 inch thick,buttermilk...
# 2504   cooking spray,frozen shredded hash browns, tha...
# 4237   all-purpose flour,egg,milk,panko bread crumbs,...
# 12232  (4 1/2 cups) white bread flour,instant dry yea...
# 2790   2% milk ,unsalted butter,eggs,salt,bread flour...
#
#                                           direction_list  ...  fiber (g)  \
# 0       Whisk together buttermilk, egg, flour, chile ...  ...        2.0
# 2504    Preheat a waffle iron according to manufactur...  ...        2.0
# 4237    Preheat an air fryer to 400 degrees F (200 de...  ...        1.0
# 12232   Place flour in a large mixing bowl. Sprinkle ...  ...        1.0
# 2790    Pour milk into a microwave-safe bowl. Heat in...  ...        1.0
#
#        sugar (g)  cholesterol (mg)  vitamin_c (mg)  calcium (mg)  iron (mg)  \
# 0            NaN              48.0             NaN           NaN        NaN
# 2504         1.0              94.0             8.0          76.0        2.0
# 4237         1.0              48.0             0.0          72.0        8.0
# 12232        3.0              18.0             0.0          40.0        2.0
# 2790         1.0              27.0             NaN          26.0        0.0
#
#        potassium (mg)                                        recipe_link  \
# 0               197.0  https://www.allrecipes.com/recipe/8465728/air-...
# 2504            433.0  https://www.allrecipes.com/recipe/255096/kitch...
# 4237             67.0  https://www.allrecipes.com/recipe/280571/air-f...
# 12232            98.0  https://www.allrecipes.com/recipe/277886/homem...
# 2790             46.0  https://www.allrecipes.com/recipe/258732/hot-u...
#
#                              main_ingredients  main_ing_len
# 0      [bread, egg, flour, lime, milk, onion]             6
# 2504                [egg, flour, milk, onion]             4
# 4237                [bread, egg, flour, milk]             4
# 12232               [bread, egg, flour, milk]             4
# 2790                [bread, egg, flour, milk]             4
#
# [5 rows x 26 columns]

# %%
ings = ['banana', 'flour', 'egg']
df = query_recipes("temp.db", 
                   ingredients=ings
                   )
df
# Out:
#                                   recipe_name        category_name  rating  \
# 13513                 Joy's Easy Banana Bread        Banana Breads     4.8
# 13477                  Raspberry Banana Bread        Banana Breads     4.6
# 13470                            Banana Bread        Banana Breads     4.7
# 13468                Lower Fat Banana Bread I        Banana Breads     4.7
# 3867             Banana Pudding Sugar Cookies        Sugar Cookies     4.2
# ...                                       ...                  ...     ...
# 4072   Slow Cooker Shredded Venison for Tacos                Tacos     4.4
# 9529                              Plain Pasta       Homemade Pasta     4.4
# 4131                 Southern-Style Egg Salad           Tailgating     4.7
# 9431                    Halloween Eye of Newt            Halloween     4.5
# 145                             Eggs n' Fries   Breakfast Potatoes     4.6
#
#        prep_time  cook_time  additional_time  total_time  \
# 13513       15.0       60.0              0.0        75.0
# 13477       25.0       60.0             30.0       115.0
# 13470       15.0       60.0              0.0        75.0
# 13468       15.0       60.0              0.0        75.0
# 3867        15.0       10.0            130.0       155.0
# ...          ...        ...              ...         ...
# 4072        15.0       45.0              0.0        60.0
# 9529        25.0       10.0            180.0       215.0
# 4131        10.0       10.0             40.0        60.0
# 9431        10.0       15.0              0.0        25.0
# 145          5.0       10.0              0.0        15.0
#
#       num_servings_per_recipe  \
# 13513                     10
# 13477                     10
# 13470                     16
# 13468                     12
# 3867                      30
# ...                       ...
# 4072                       7
# 9529                       4
# 4131                      10
# 9431                      12
# 145                        1
#
#                                         ingredients_list  \
# 13513  ripe bananas, mashed,white sugar,egg,melted bu...
# 13477  frozen unsweetened raspberries, thawed,ripe ba...
# 13470  all-purpose flour,white sugar,baking soda,salt...
# 13468  white sugar,margarine, softened,eggs,mashed ba...
# 3867   shortening,white sugar,eggs,vanilla extract,ba...
# ...                                                  ...
# 4072   taco seasoning mix,all-purpose flour,venison r...
# 9529   semolina flour,salt,baking powder,warm water,b...
# 4131   eggs,mayonnaise,sweet India pickle relish,yell...
# 9431   eggs,sweet pickle relish,mayonnaise,celery sal...
# 145    butter, or to taste,frozen French fries, or to...
#
#                                           direction_list  ...  fiber (g)  \
# 13513   Gather all ingredients. Preheat the oven to 3...  ...        1.0
# 13477   Preheat oven to 325 degrees F (165 degrees C)...  ...        1.0
# 13470   Preheat the oven to 350 degrees F (175 degree...  ...        1.0
# 13468   Preheat oven to 350 degrees F (175 degrees C)...  ...        1.0
# 3867    In a medium bowl, cream together shortening a...  ...        0.0
# ...                                                  ...  ...        ...
# 4072    Mix half the taco seasoning with the flour an...  ...        0.0
# 9529    Mix together flour, salt baking powder. Add w...  ...        NaN
# 4131    Cover eggs with water in a saucepan, bring to...  ...        0.0
# 9431    Gather all ingredients.\nAllrecipes/Julia Har...  ...        1.0
# 145     Melt butter in a skillet over medium heat. Ad...  ...        0.0
#
#        sugar (g)  cholesterol (mg)  vitamin_c (mg)  calcium (mg)  iron (mg)  \
# 13513       24.0              31.0             3.0           9.0        1.0
# 13477       22.0              37.0             2.0          12.0        1.0
# 13470       15.0              31.0             2.0           7.0        1.0
# 13468       14.0              31.0             2.0          15.0        1.0
# 3867         7.0              12.0             NaN           8.0        1.0
# ...          ...               ...             ...           ...        ...
# 4072         1.0             235.0             0.0          14.0       10.0
# 9529         NaN               8.0             NaN          14.0        NaN
# 4131         2.0             114.0             1.0          17.0        1.0
# 9431         1.0             186.0             0.0          40.0        1.0
# 145          1.0             383.0             4.0          56.0        2.0
#
#        potassium (mg)                                        recipe_link  \
# 13513           155.0  https://www.allrecipes.com/recipe/241707/joys-...
# 13477            77.0  https://www.allrecipes.com/recipe/228442/raspb...
# 13470           101.0  https://www.allrecipes.com/recipe/6687/banana-...
# 13468            99.0  https://www.allrecipes.com/recipe/6754/lower-f...
# 3867             16.0  https://www.allrecipes.com/recipe/11159/banana...
# ...               ...                                                ...
# 4072            500.0  https://www.allrecipes.com/recipe/18853/slow-c...
# 9529              1.0  https://www.allrecipes.com/recipe/23703/plain-...
# 4131             45.0  https://www.allrecipes.com/recipe/280034/south...
# 9431             71.0  https://www.allrecipes.com/recipe/128664/hallo...
# 145             228.0  https://www.allrecipes.com/recipe/242100/eggs-...
#
#            main_ingredients  main_ing_len
# 13513  [banana, egg, flour]             3
# 13477  [banana, egg, flour]             3
# 13470  [banana, egg, flour]             3
# 13468  [banana, egg, flour]             3
# 3867   [banana, egg, flour]             3
# ...                     ...           ...
# 4072                [flour]             1
# 9529                [flour]             1
# 4131                  [egg]             1
# 9431                  [egg]             1
# 145                   [egg]             1
#
# [610 rows x 26 columns]

# %%
df = query_recipes("temp.db", 
                   min_calories=1000
                   )
df.head()
# Out:
#                         recipe_name          category_name  rating  prep_time  \
# 0           Zucchini Bread in a Jar        Zucchini Breads     4.7       30.0
# 1  Overnight French Toast Casserole   Breakfast Casseroles     4.7       15.0
# 2     Carne Asada Breakfast Burrito     Breakfast Potatoes     4.8       15.0
# 3              Annie's Turkey Brine                 Brines     4.8       10.0
# 4        Brined Thanksgiving Turkey                 Brines     4.9       30.0
#
#    cook_time  additional_time  total_time num_servings_per_recipe  \
# 0       60.0            120.0       210.0                      4
# 1       45.0            480.0       540.0                      5
# 2       35.0              0.0        50.0                      4
# 3        5.0             30.0        45.0                      1
# 4      390.0              0.0       420.0                     12
#
#                                     ingredients_list  \
# 0  raisins,hot water,shortening for greasing,whit...
# 1  butter, melted,light brown sugar,cinnamon,Fren...
# 2  beef skirt steak, cut into thin strips,carne a...
# 3  water,apple cider,brown sugar,oranges, sliced,...
# 4  chicken broth,apple juice (Optional),light bro...
#
#                                       direction_list  ...  fiber (g)  \
# 0   Preheat the oven to 325 degrees F (165 degree...  ...        7.0
# 1   Pour melted butter into an 11x15-inch baking ...  ...        3.0
# 2   Place beef slices in a mixing bowl. Sprinkle ...  ...        7.0
# 3   Stir water, apple cider, brown sugar, orange ...  ...       16.0
# 4   Gather all ingredients.\nALLRECIPES / QI AI, ...  ...        3.0
#
#    sugar (g)  cholesterol (mg)  vitamin_c (mg)  calcium (mg)  iron (mg)  \
# 0      102.0             140.0            12.0         126.0        6.0
# 1       93.0             367.0             0.0         285.0        5.0
# 2        9.0             437.0            42.0         641.0        9.0
# 3      575.0               NaN           196.0         953.0       13.0
# 4       31.0             455.0             6.0         191.0       10.0
#
#    potassium (mg)                                        recipe_link  \
# 0           734.0  https://www.allrecipes.com/recipe/256341/zucch...
# 1           490.0  https://www.allrecipes.com/recipe/275838/overn...
# 2          1043.0  https://www.allrecipes.com/recipe/256301/carne...
# 3          1690.0  https://www.allrecipes.com/recipe/234091/annie...
# 4          1710.0  https://www.allrecipes.com/recipe/234092/brine...
#
#                                     main_ingredients  main_ing_len
# 0                               egg, flour, zucchini             3
# 1                                   bread, egg, milk             3
# 2  beef, bell pepper, cheese, egg, flour, jalapen...            10
# 3                                      apple, orange             2
# 4                apple, chicken, corn, onion, turkey             5
#
# [5 rows x 26 columns]

# %%
df = query_recipes("temp.db", 
                   max_calories=1000
                   )
df.head()
# Out:
#                                 recipe_name         category_name  rating  \
# 0               Air Fryer Spicy Onion Rings     Air Fryer Recipes     5.0
# 1               Stuffed Chicken Cordon Bleu   Chicken Cordon Bleu     5.0
# 2  Hearty Chicken Cacciatore Soup with Rice    Chicken Cacciatore     NaN
# 3                     Margo's Chicken Adobo         Chicken Adobo     4.5
# 4                   Run For The Roses Pie I             Chess Pie     4.2
#
#    prep_time  cook_time  additional_time  total_time num_servings_per_recipe  \
# 0       20.0       10.0             30.0        60.0                      4
# 1       20.0       40.0             15.0        75.0                      4
# 2       10.0      105.0              0.0       115.0                     10
# 3       10.0       60.0              0.0        70.0                      8
# 4       30.0       45.0              5.0        80.0                     16
#
#                                     ingredients_list  \
# 0  sweet onions, sliced 1/2 inch thick,buttermilk...
# 1  skinless, boneless chicken breast halves,bacon...
# 2  chicken broth,condensed tomato soup,water,dice...
# 3  canola oil,chicken drumsticks and thighs,onion...
# 4  chopped walnuts,bourbon,white sugar,light corn...
#
#                                       direction_list  ...  fiber (g)  \
# 0   Whisk together buttermilk, egg, flour, chile ...  ...        2.0
# 1   Preheat the oven to 400 degrees F (200 degree...  ...        3.0
# 2   Combine chicken broth, condensed soup, 2 cans...  ...        2.0
# 3   Heat canola oil in a large Dutch oven over me...  ...        1.0
# 4   Preheat oven to 350 degrees F (175 degrees C)...  ...        2.0
#
#    sugar (g)  cholesterol (mg)  vitamin_c (mg)  calcium (mg)  iron (mg)  \
# 0        NaN              48.0             NaN           NaN        NaN
# 1        8.0             291.0             3.0         636.0        4.0
# 2        NaN              38.0             NaN           NaN        NaN
# 3        2.0              96.0             3.0          40.0        3.0
# 4       24.0              62.0             0.0          24.0        1.0
#
#    potassium (mg)                                        recipe_link  \
# 0           197.0  https://www.allrecipes.com/recipe/8465728/air-...
# 1           969.0  https://www.allrecipes.com/recipe/283793/stuff...
# 2           406.0  https://www.allrecipes.com/recipe/8300735/hear...
# 3           347.0  https://www.allrecipes.com/recipe/218510/margo...
# 4           104.0  https://www.allrecipes.com/recipe/23165/run-fo...
#
#                                     main_ingredients  main_ing_len
# 0               bread, egg, flour, lime, milk, onion             6
# 1  apple, bacon, bread, cheese, chicken, corn, eg...             9
# 2           chicken, mushroom, onion, rice, tomatoes             5
# 3                        apple, chicken, corn, onion             4
# 4                               chocolate, corn, egg             3
#
# [5 rows x 26 columns]

# %%
df = query_recipes("temp.db", 
                   ingredients=["lime", "apple", "orange", 'flour', "cherries", 'milk'],
                   max_calories=200,
                   min_calories=100,
                   time = 60
                   )
df.head()
# Out:
#                             recipe_name       category_name  rating  \
# 1703  Spiced Apple Topping for Pancakes          Applesauce     4.0
# 426         Nana Dot's Irish Soda Bread   St. Patrick's Day     4.8
# 655                        Apple Scones              Scones     4.2
# 21             Mighty Fine Turkey Brine              Brines     5.0
# 1079                     Keto Margarita          Margaritas     4.9
#
#       prep_time  cook_time  additional_time  total_time  \
# 1703       10.0       25.0              0.0        35.0
# 426        15.0       30.0              0.0        45.0
# 655        15.0       15.0              0.0        30.0
# 21         25.0       16.0              0.0        41.0
# 1079       10.0        NaN              NaN        10.0
#
#      num_servings_per_recipe  \
# 1703                      6
# 426                      24
# 655                      12
# 21                       31
# 1079                      1
#
#                                        ingredients_list  \
# 1703  all-purpose flour,ground cinnamon,ground nutme...
# 426   all-purpose flour,baking soda,baking powder,sa...
# 655   all-purpose flour,white sugar,baking powder,ba...
# 21    water, divided,salt,water,packed dark brown su...
# 1079  ice,tequila,lime juice,low-calorie natural swe...
#
#                                          direction_list  ...  fiber (g)  \
# 1703   Preheat the oven to 375 degrees F (190 degree...  ...        3.0
# 426    Preheat oven to 400 degrees F (200 degrees C)...  ...        1.0
# 655    Measure flour, sugar, baking powder, soda, an...  ...        1.0
# 21     Combine 2 1/2 cups water and salt in a small ...  ...        1.0
# 1079   Fill a shaker half-full with ice. Add tequila...  ...        0.0
#
#       sugar (g)  cholesterol (mg)  vitamin_c (mg)  calcium (mg)  iron (mg)  \
# 1703       20.0               NaN             5.0          30.0        0.0
# 426         8.0              11.0             0.0          53.0        1.0
# 655         8.0              11.0             1.0          66.0        1.0
# 21         15.0               NaN             6.0          20.0        0.0
# 1079        1.0               NaN            12.0          32.0        0.0
#
#       potassium (mg)                                        recipe_link  \
# 1703           157.0  https://www.allrecipes.com/recipe/285360/spice...
# 426            109.0  https://www.allrecipes.com/recipe/161706/nana-...
# 655             56.0  https://www.allrecipes.com/recipe/6905/apple-s...
# 21             107.0  https://www.allrecipes.com/recipe/254489/might...
# 1079            55.0  https://www.allrecipes.com/recipe/266764/keto-...
#
#           main_ingredients  main_ing_len
# 1703  [apple, flour, milk]             3
# 426   [apple, flour, milk]             3
# 655   [apple, flour, milk]             3
# 21         [apple, orange]             2
# 1079        [lime, orange]             2
#
# [5 rows x 26 columns]
